# %%
import numpy as np
import pandas as pd

# %%
stations = (pd.read_csv('stations.csv')
              .loc[:,['id', 'latitude', 'longitude']])

# %%
len(stations)
# Out:
# 198

# %%
stations.to_json(orient='records')
# Out:
# '[{"id":144,"latitude":-34.6339776264,"longitude":-58.4009623109},{"id":50,"latitude":-34.6016384998,"longitude":-58.3711554749},{"id":135,"latitude":-34.6123893029,"longitude":-58.3807663115},{"id":128,"latitude":-34.5998125733,"longitude":-58.4429012739},{"id":145,"latitude":-34.5982221816,"longitude":-58.4217046053},{"id":3,"latitude":-34.611242025,"longitude":-58.3689178426},{"id":95,"latitude":-34.5946161106,"longitude":-58.4090340035},{"id":127,"latitude":-34.6118079129,"longitude":-58.3609057985},{"id":24,"latitude":-34.6105722194,"longitude":-58.3807669356},{"id":214,"latitude":-34.6107962769,"longitude":-58.433506016},{"id":22,"latitude":-34.5940998363,"longitude":-58.3825704592},{"id":212,"latitude":-34.5911108808,"longitude":-58.4059738535},{"id":155,"latitude":-34.5854242215,"longitude":-58.4210441536},{"id":190,"latitude":-34.5905542157,"longitude":-58.4288881957},{"id":102,"latitude":-34.592672512,"longitude":-58.425816436},{"id":226,"latitude":-34.5881914581,"longitude
# ...

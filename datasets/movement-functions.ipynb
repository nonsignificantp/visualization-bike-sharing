# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
plt.plot([((-1*x**2) + 2*x) for x in np.arange(0,1,0.01)])

# %% [markdown]
# x = cx + r * cos(a)
# y = cy + r * sin(a)

# %%
plt.plot([((-1*x**2) + 2*x) for x in np.arange(0,1,0.01)])

# %%
time = [np.cos(np.radians((90 *x)))*150 for x in np.arange(0,1,0.01)]
prop = [np.sin(np.radians((180*x)))     for x in np.arange(0,1,0.01)]

plt.plot(time, prop)

# %%
time = np.array([np.cos(np.radians((90 *x)))     for x in np.arange(0,1,0.00667)])
prop = np.array([np.sin(np.radians((180*x)))     for x in np.arange(0,1,0.00667)])

plt.plot(time,prop)

# %%
for i,z in zip(reversed(time), prop)[1:]:
    print(i/z)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-105-490cddb3ea37> in <module>()
# ----> 1 for i,z in zip(reversed(time), prop)[1:]:
#       2     print(i/z)
#
# TypeError: 'zip' object is not subscriptable

# %%
prop
# Out:
# array([0.        , 0.02095289, 0.04189658, 0.06282187, 0.08371958,
#        0.10458054, 0.12539557, 0.14615555, 0.16685135, 0.18747389,
#        0.20801412, 0.22846302, 0.2488116 , 0.26905094, 0.28917214,
#        0.30916638, 0.32902487, 0.3487389 , 0.3682998 , 0.387699  ,
#        0.40692797, 0.42597826, 0.44484152, 0.46350947, 0.4819739 ,
#        0.50022671, 0.51825988, 0.5360655 , 0.55363575, 0.57096291,
#        0.58803938, 0.60485766, 0.62141036, 0.63769022, 0.65369009,
#        0.66940294, 0.68482187, 0.69994012, 0.71475104, 0.72924814,
#        0.74342505, 0.75727553, 0.77079352, 0.78397308, 0.79680841,
#        0.80929389, 0.82142403, 0.83319351, 0.84459715, 0.85562996,
#        0.86628708, 0.87656385, 0.88645573, 0.8959584 , 0.90506768,
#        0.91377957, 0.92209024, 0.92999605, 0.93749353, 0.94457938,
#        0.95125049, 0.95750393, 0.96333696, 0.96874702, 0.97373173,
#        0.9782889 , 0.98241652, 0.9861128 , 0.98937611, 0.992205  ,
# ...

# %%
plt.plot(time)
plt.plot((0,1500), (150,150))

# %%
150/100
# Out:
# 1.5

# %%
plt.plot((np.array([np.sin(np.radians((180*x)))     for x in np.arange(0,1,0.01)])*(np.array([np.cos(np.radians((90 *x)))*150 for x in np.arange(0,1,0.01)])-150)*-1)/60)

# %%
fig, ax = plt.subplots(1,1,figsize=(5,5))
ax.plot([np.sin(np.radians((90*x))) for x in np.arange(0,1,0.01)], [1-np.cos(np.radians((90*(x)))) for x in np.arange(0,1,0.01)])
i = 1.1

ax.plot([np.sin(np.radians((90*x))) for x in np.arange(0,1,0.01)], [1-np.cos(np.radians((90*(x)))) for x in np.arange(0,1,0.01)])

# %%
x = [1-(np.cos(np.multiply(90*x, (np.pi)/180))) for x in np.arange(0,1,0.01)]
y = [  (np.sin(np.multiply(90*x, (np.pi)/180))) for x in np.arange(0,1,0.01)]

(plt.plot(x,y))
(plt.plot(np.power(x,0.4),np.power(y,0.4)))
(plt.plot(np.power(x,2),np.power(y,2)))
